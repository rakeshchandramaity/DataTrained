# %% [markdown]
# # Avacado Project

# %% [markdown]
# ### Problem Statement:
#
# Avocado is a fruit consumed by people heavily in the United States.
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %% [raw]
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold

# %% [raw]
# Inspiration /Label
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.
#
# To download the dataset, use the link given below.

# %%
# Importing main required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn import linear_model
from sklearn import model_selection
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns



from sklearn.metrics import roc_curve

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

#from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
plt.style.use('fivethirtyeight') # Good looking plots
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import logit, probit, poisson, ols
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC




# Not to display warnings.

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the given data set
data=pd.read_csv('/Users/rakeshchandramaity/Desktop/ml/avocado.csv')

# %%
df=data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
# Head Checking
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27/12/2015          1.33      64236.62  1036.74   54454.85
# 1           1  20/12/2015          1.35      54876.98   674.28   44638.81
# 2           2  13/12/2015          0.93     118220.22   794.70  109149.67
# 3           3  06/12/2015          1.08      78992.15  1132.00   71976.41
# 4           4  29/11/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
# Tail Checking
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  04/02/2018          1.63      17074.83  2046.96  1529.20
# 18245           8  28/01/2018          1.71      13888.04  1191.70  3431.50
# 18246           9  21/01/2018          1.87      13766.76  1191.92  2452.79
# 18247          10  14/01/2018          1.93      16205.22  1527.63  2981.04
# 18248          11  07/01/2018          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
# As per problem description replacing the column name
df = data.rename(columns={'4046':'PLU_4046','4225':'PLU_4225','4770':'PLU_4770'})

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  \
# 0           0  27/12/2015          1.33      64236.62   1036.74   54454.85
# 1           1  20/12/2015          1.35      54876.98    674.28   44638.81
# 2           2  13/12/2015          0.93     118220.22    794.70  109149.67
# 3           3  06/12/2015          1.08      78992.15   1132.00   71976.41
# 4           4  29/11/2015          1.28      51039.60    941.48   43838.39
#
#    PLU_4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25          0.0  conventional
# 1     58.33     9505.56     9408.07       97.49          0.0  conventional
# 2    130.50     8145.35     8042.21      103.14          0.0  conventional
# 3     72.58     5811.16     5677.40      133.76          0.0  conventional
# 4     75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
# checking the columns of the data

df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', 'PLU_4046',
#        'PLU_4225', 'PLU_4770', 'Total Bags', 'Small Bags', 'Large Bags',
#        'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
# removing unnecessary column
data = df.drop(['Unnamed: 0'],axis = 1)
data.head(10)
# Out:
#          Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0  27/12/2015          1.33      64236.62   1036.74   54454.85     48.16
# 1  20/12/2015          1.35      54876.98    674.28   44638.81     58.33
# 2  13/12/2015          0.93     118220.22    794.70  109149.67    130.50
# 3  06/12/2015          1.08      78992.15   1132.00   71976.41     72.58
# 4  29/11/2015          1.28      51039.60    941.48   43838.39     75.78
# 5  22/11/2015          1.26      55979.78   1184.27   48067.99     43.61
# 6  15/11/2015          0.99      83453.76   1368.92   73672.72     93.26
# 7  08/11/2015          0.98     109428.33    703.75  101815.36     80.00
# 8  01/11/2015          1.02      99811.42   1022.15   87315.57     85.34
# 9  25/10/2015          1.07      74338.76    842.40   64757.44    113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany
# 5     6683.91     6556.47      127.44          0.0  conventional  2015  Albany
# 6     8318.86     8196.81      122.05          0.0  conventional  2015  Albany
# 7     6829.22     6266.85      562.37          0.0  conventional  2015  Albany
# 8    11388.36    11104.53      283.83          0.0  conventional  2015  Albany
# 9     8625.92     8061.47      564.45          0.0  conventional  2015  Albany

# %%
# So now checking all the data are in numeric form or Not
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   PLU_4046      18249 non-null  float64
#  4   PLU_4225      18249 non-null  float64
#  5   PLU_4770      18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
data['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
data.head(10)
# Out:
#          Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0  27/12/2015          1.33      64236.62   1036.74   54454.85     48.16
# 1  20/12/2015          1.35      54876.98    674.28   44638.81     58.33
# 2  13/12/2015          0.93     118220.22    794.70  109149.67    130.50
# 3  06/12/2015          1.08      78992.15   1132.00   71976.41     72.58
# 4  29/11/2015          1.28      51039.60    941.48   43838.39     75.78
# 5  22/11/2015          1.26      55979.78   1184.27   48067.99     43.61
# 6  15/11/2015          0.99      83453.76   1368.92   73672.72     93.26
# 7  08/11/2015          0.98     109428.33    703.75  101815.36     80.00
# 8  01/11/2015          1.02      99811.42   1022.15   87315.57     85.34
# 9  25/10/2015          1.07      74338.76    842.40   64757.44    113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany
# 5     6683.91     6556.47      127.44          0.0  conventional  2015  Albany
# 6     8318.86     8196.81      122.05          0.0  conventional  2015  Albany
# 7     6829.22     6266.85      562.37          0.0  conventional  2015  Albany
# 8    11388.36    11104.53      283.83          0.0  conventional  2015  Albany
# 9     8625.92     8061.47      564.45          0.0  conventional  2015  Albany

# %%
#pairplot
import seaborn as sns
sns.pairplot(df)

# %%
df.hist(figsize=(15,20),bins=50)
plt.show()

# %%
df.plot(kind ='density',subplots = True, layout =(6,2),sharex = False,figsize=(20, 10))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
#Getting summary metrics for the dataframe
print(df.describe())
# Out:
#          Unnamed: 0  AveragePrice  Total Volume      PLU_4046      PLU_4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#            PLU_4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.plot(kind='box',color='r',vert = False,figsize =(14,8))    #Box Plot
# Out:
# <AxesSubplot:>

# %%
threshold=3
print(np.where(z>3))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt= '.2f')
# Out:
# <AxesSubplot:>

# %%
# convert the type of Date feature from obj to datetime type
data['Date'] = pd.to_datetime(data['Date'])

# %%
# categorizing into several seasons
def season_of_date(date):
    year = str(date.year)
    seasons = {'spring': pd.date_range(start='21/03/'+year, end='20/06/'+year),
               'summer': pd.date_range(start='21/06/'+year, end='22/09/'+year),
               'autumn': pd.date_range(start='23/09/'+year, end='20/12/'+year)}
    if date in seasons['spring']:
        return 'spring'
    if date in seasons['summer']:
        return 'summer'
    if date in seasons['autumn']:
        return 'autumn'
    else:
        return 'winter'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
print (data.Date)
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-06-12
# 4       2015-11-29
#            ...
# 18244   2018-04-02
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-07-01
# Name: Date, Length: 18249, dtype: datetime64[ns]

# %%
# creating a new feature 'season' and assign the corresponding season for the Date using map function over our season_of_date function
data['season'] = data.Date.map(season_of_date)

# %%
# now, we can see the season feature appended at the last
data.head(10)
# Out:
#         Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0 2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1 2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2 2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3 2015-06-12          1.08      78992.15   1132.00   71976.41     72.58
# 4 2015-11-29          1.28      51039.60    941.48   43838.39     75.78
# 5 2015-11-22          1.26      55979.78   1184.27   48067.99     43.61
# 6 2015-11-15          0.99      83453.76   1368.92   73672.72     93.26
# 7 2015-08-11          0.98     109428.33    703.75  101815.36     80.00
# 8 2015-01-11          1.02      99811.42   1022.15   87315.57     85.34
# 9 2015-10-25          1.07      74338.76    842.40   64757.44    113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
# 5     6683.91     6556.47      127.44          0.0  conventional  2015
# 6     8318.86     8196.81      122.05          0.0  conventional  2015
# 7     6829.22     6266.85      562.37          0.0  conventional  2015
# 8    11388.36    11104.53      283.83          0.0  conventional  2015
# 9     8625.92     8061.47      564.45          0.0  conventional  2015
#
#    region  season
# 0  Albany  winter
# 1  Albany  autumn
# 2  Albany  autumn
# 3  Albany  spring
# 4  Albany  autumn
# 5  Albany  autumn
# 6  Albany  autumn
# 7  Albany  summer
# 8  Albany  winter
# 9  Albany  autumn

# %%
# no of observations for each seasons
data.season.value_counts()
# Out:
# winter    4860
# autumn    4536
# spring    4534
# summer    4319
# Name: season, dtype: int64

# %%
# droping date feature
data = data.drop(['Date'],axis = 1)

# %% [markdown]
# # Data Preprocessing

# %%
# converting categorical features of text data into model-understandable numerical data
label_cols = ['type','region','season']
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
data[label_cols] = data[label_cols].apply(lambda x : label.fit_transform(x))

# %%
# Scaling the features and 
# spliting the label encoded features into distinct features inorder to prevent our model to think that columns have data with some kind of order or hierarchy
# column_tranformer allows us to combine several feature extraction or transformation methods into a single transformer
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
scale_cols = data.drop(['AveragePrice','type','year','region','season'],axis=1)
col_trans = make_column_transformer(
            (OneHotEncoder(), data[label_cols].columns),
            (StandardScaler(), scale_cols.columns),
            remainder = 'passthrough')

# %% [markdown]
# # Train Test Split

# %%
# splitting our dataset into train and test set such that 20% of observations are considered as test set
X = data.drop(['AveragePrice'],axis=1)
y = data.AveragePrice
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# # Regression Models for Average Price Calculation

# %% [markdown]
# ## 1. Linear Regression

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
pipe = make_pipeline(col_trans,linreg)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   Index(['type', 'region', 'season'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Total Volume', 'PLU_4046', 'PLU_4225', 'PLU_4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags'],
#       dtype='object'))])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_test = pipe.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print('MAE for testing set: {}'.format(mean_absolute_error(y_pred_test,y_test)))
print('MSE for testing set: {}'.format(mean_squared_error(y_pred_test,y_test)))
print('RMSE for testing set: {}'.format(np.sqrt(mean_squared_error(y_pred_test,y_test))))
# Out:
# MAE for testing set: 0.19940553474978517
# MSE for testing set: 0.07101420449392358
# RMSE for testing set: 0.26648490481436954

# %% [markdown]
# ## 2. Support Vector Regressor (SVR)

# %%
from sklearn.svm import SVR
svr = SVR()
pipe = make_pipeline(col_trans,svr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   Index(['type', 'region', 'season'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Total Volume', 'PLU_4046', 'PLU_4225', 'PLU_4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags'],
#       dtype='object'))])),
#                 ('svr', SVR())])

# %%
y_pred_test = pipe.predict(X_test)

# %%
print('MAE for testing set: {}'.format(mean_absolute_error(y_pred_test,y_test)))
print('MSE for testing set: {}'.format(mean_squared_error(y_pred_test,y_test)))
print('RMSE for testing set: {}'.format(np.sqrt(mean_squared_error(y_pred_test,y_test))))
# Out:
# MAE for testing set: 0.3212244072520755
# MSE for testing set: 0.1630772983436882
# RMSE for testing set: 0.4038283030493135

# %% [markdown]
# # 3. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dr=DecisionTreeRegressor()
pipe = make_pipeline(col_trans,dr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   Index(['type', 'region', 'season'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Total Volume', 'PLU_4046', 'PLU_4225', 'PLU_4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags'],
#       dtype='object'))])),
#                 ('decisiontreeregressor', DecisionTreeRegressor())])

# %%
y_pred_test = pipe.predict(X_test)

# %%
print('MAE for testing set: {}'.format(mean_absolute_error(y_pred_test,y_test)))
print('MSE for testing set: {}'.format(mean_squared_error(y_pred_test,y_test)))
print('RMSE for testing set: {}'.format(np.sqrt(mean_squared_error(y_pred_test,y_test))))
# Out:
# MAE for testing set: 0.14734794520547945
# MSE for testing set: 0.052158082191780815
# RMSE for testing set: 0.2283814401210852

# %% [markdown]
# ## 4. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model = RandomForestRegressor()
pipe = make_pipeline(col_trans,forest_model)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   Index(['type', 'region', 'season'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Total Volume', 'PLU_4046', 'PLU_4225', 'PLU_4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags'],
#       dtype='object'))])),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
print('MAE for testing set: {}'.format(mean_absolute_error(y_pred_test,y_test)))
print('MSE for testing set: {}'.format(mean_squared_error(y_pred_test,y_test)))
print('RMSE for testing set: {}'.format(np.sqrt(mean_squared_error(y_pred_test,y_test))))
# Out:
# MAE for testing set: 0.14734794520547945
# MSE for testing set: 0.052158082191780815
# RMSE for testing set: 0.2283814401210852

# %%
sns.distplot((y_test-y_pred_test),bins=50)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# # Now Predicttion on the Region based on Classification

# %%
X_c = df.drop(['region','Date','type'], axis = 1)
Y_c = df['region']
print(X_c.shape)
print(Y_c.shape)
# Out:
# (18249, 11)
# (18249,)

# %%
#Standardization
sc=StandardScaler()
sc.fit_transform(X_c)
X_c=pd.DataFrame(X_c,columns=X_c.columns)

# %%
#Nw by using multiple Algo we are calculating the best algo
model = [KNeighborsClassifier(),DecisionTreeClassifier()]
max_accuracy_score = 0
for r_state in range(40,90):
    train_xc,test_xc,train_yc,test_yc = train_test_split(X_c,Y_c,random_state = r_state,test_size=0.33)
    for i_c in model:
        i_c.fit(train_xc,train_yc)
        pre_c = i_c.predict(test_xc)
        ac_score = accuracy_score(test_yc,pre_c)
        print ("accuracy score correspond to random state ",r_state, "is",ac_score)
        if ac_score>max_accuracy_score:
            max_accuracy_score=ac_score
            final_state = r_state
            final_model = i_c
            
print()
print()
print()
print()

print("max accuracy score correspond to random state ", final_state, "is",max_accuracy_score ,"and model is",final_model)
# Out:
# accuracy score correspond to random state  40 is 0.6465216669433836
# accuracy score correspond to random state  40 is 0.782002324423045
# accuracy score correspond to random state  41 is 0.6456915158558858
# accuracy score correspond to random state  41 is 0.7665615141955836
# accuracy score correspond to random state  42 is 0.6466876971608833
# accuracy score correspond to random state  42 is 0.7831645359455421
# accuracy score correspond to random state  43 is 0.6395483978084011
# accuracy score correspond to random state  43 is 0.7717084509380707
# accuracy score correspond to random state  44 is 0.65200066412087
# accuracy score correspond to random state  44 is 0.7738668437655654
# accuracy score correspond to random state  45 is 0.6498422712933754
# accuracy score correspond to random state  45 is 0.7790137805080525
# accuracy score correspond to random state  46 is 0.6436991532458908
# accuracy score correspond to random state  46 is 0.7825004150755438
# accuracy score correspond to random state  47 is 0.6470197575958825
# accuracy score correspond to random state  47 is 0.7828324755105429
# accuracy score correspond to random state  48 is 0.6515025734683713
# accuracy score correspond to random state  48 is 0.78797941225303
# accuracy score correspond to random state  49 is 0.6518346339033704
# accuracy score correspond to random state  49 is 0.7786817200730533
# accuracy score correspond to random state  50 is 0.6387182467209032
# accuracy score correspond to random state  50 is 0.78399468703304
# accuracy score correspond to random state  51 is 0.6468537273783829
# accuracy score correspond to random state  51 is 0.7858210194255354
# accuracy score correspond to random state  52 is 0.645193425203387
# accuracy score correspond to random state  52 is 0.78399468703304
# accuracy score correspond to random state  53 is 0.6554872986883613
# accuracy score correspond to random state  53 is 0.7770214178980575
# accuracy score correspond to random state  54 is 0.6524987547733687
# accuracy score correspond to random state  54 is 0.7903038352980243
# accuracy score correspond to random state  55 is 0.6441972438983895
# accuracy score correspond to random state  55 is 0.7803420222480492
# accuracy score correspond to random state  56 is 0.6398804582434003
# accuracy score correspond to random state  56 is 0.7755271459405612
# accuracy score correspond to random state  57 is 0.6498422712933754
# accuracy score correspond to random state  57 is 0.7858210194255354
# accuracy score correspond to random state  58 is 0.6466876971608833
# accuracy score correspond to random state  58 is 0.7838286568155405
# accuracy score correspond to random state  59 is 0.6546571476008634
# accuracy score correspond to random state  59 is 0.785987049643035
# accuracy score correspond to random state  60 is 0.6496762410758758
# accuracy score correspond to random state  60 is 0.7806740826830483
# accuracy score correspond to random state  61 is 0.6485140295533787
# accuracy score correspond to random state  61 is 0.7775195085505562
# accuracy score correspond to random state  62 is 0.6554872986883613
# accuracy score correspond to random state  62 is 0.7848248381205379
# accuracy score correspond to random state  63 is 0.6521666943383696
# accuracy score correspond to random state  63 is 0.7866511705130333
# accuracy score correspond to random state  64 is 0.6534949360783663
# accuracy score correspond to random state  64 is 0.7881454424705296
# accuracy score correspond to random state  65 is 0.6503403619458742
# accuracy score correspond to random state  65 is 0.7818362942055455
# accuracy score correspond to random state  66 is 0.6544911173833637
# accuracy score correspond to random state  66 is 0.7919641374730201
# accuracy score correspond to random state  67 is 0.6436991532458908
# accuracy score correspond to random state  67 is 0.7795118711605512
# accuracy score correspond to random state  68 is 0.6515025734683713
# accuracy score correspond to random state  68 is 0.7808401129005479
# accuracy score correspond to random state  69 is 0.6420388510708949
# accuracy score correspond to random state  69 is 0.7815042337705462
# accuracy score correspond to random state  70 is 0.6573136310808567
# accuracy score correspond to random state  70 is 0.7785156898555537
# accuracy score correspond to random state  71 is 0.6488460899883779
# accuracy score correspond to random state  71 is 0.78399468703304
# accuracy score correspond to random state  72 is 0.6515025734683713
# accuracy score correspond to random state  72 is 0.7834965963805413
# accuracy score correspond to random state  73 is 0.6490121202058775
# accuracy score correspond to random state  73 is 0.7783496596380541
# accuracy score correspond to random state  74 is 0.638386186285904
# accuracy score correspond to random state  74 is 0.7810061431180475
# accuracy score correspond to random state  75 is 0.6468537273783829
# accuracy score correspond to random state  75 is 0.7853229287730367
# accuracy score correspond to random state  76 is 0.6475178482483812
# accuracy score correspond to random state  76 is 0.7728706624605678
# accuracy score correspond to random state  77 is 0.647185787813382
# accuracy score correspond to random state  77 is 0.7697160883280757
# accuracy score correspond to random state  78 is 0.65598538934086
# accuracy score correspond to random state  78 is 0.7825004150755438
# accuracy score correspond to random state  79 is 0.6486800597708783
# accuracy score correspond to random state  79 is 0.77204051137307
# accuracy score correspond to random state  80 is 0.647185787813382
# accuracy score correspond to random state  80 is 0.782002324423045
# accuracy score correspond to random state  81 is 0.6508384525983729
# accuracy score correspond to random state  81 is 0.7717084509380707
# accuracy score correspond to random state  82 is 0.6506724223808733
# accuracy score correspond to random state  82 is 0.7788477502905529
# accuracy score correspond to random state  83 is 0.6634567491283414
# accuracy score correspond to random state  83 is 0.7793458409430516
# accuracy score correspond to random state  84 is 0.6455254856383862
# accuracy score correspond to random state  84 is 0.7863191100780342
# accuracy score correspond to random state  85 is 0.654823177818363
# accuracy score correspond to random state  85 is 0.7791798107255521
# accuracy score correspond to random state  86 is 0.6436991532458908
# accuracy score correspond to random state  86 is 0.7833305661630416
# accuracy score correspond to random state  87 is 0.6385522165034037
# accuracy score correspond to random state  87 is 0.7806740826830483
# accuracy score correspond to random state  88 is 0.6536609662958659
# accuracy score correspond to random state  88 is 0.7871492611655321
# accuracy score correspond to random state  89 is 0.6526647849908683
# accuracy score correspond to random state  89 is 0.7831645359455421
#
#
#
#
# max accuracy score correspond to random state  66 is 0.7919641374730201 and model is DecisionTreeClassifier()

# %%
train_xc,test_xc,train_yc,test_yc = train_test_split(X_c,Y_c,random_state=76,test_size=0.33)
DCT = DecisionTreeClassifier()
parameters={'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
gridsearch=GridSearchCV(DTC,parameters)
gridsearch.fit(train_xc,train_yc)
gridsearch.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 14}

# %%
DCT = DecisionTreeClassifier(criterion = 'entropy', max_depth = 14)
DCT.fit(train_xc,train_yc)
pre_c = DCT.predict(test_xc)
ac_score = accuracy_score(test_yc,pre_c)
print ("accuracy score correspond to random state is",ac_score*100)
# Out:
# accuracy score correspond to random state is 77.63572970280592

# %%
DCT1 = DecisionTreeClassifier()
DCT1.fit(train_xc,train_yc)
pre_c = DCT1.predict(test_xc)
ac_score1 = accuracy_score(test_yc,pre_c)
print ("accuracy score correspond to random state is",ac_score1*100)
# Out:
# accuracy score correspond to random state is 76.7557695500581

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
score = cross_val_score(DCT,X_c,Y_c,cv=100,scoring='accuracy').mean()
print('Cross_val_score : ',score*100)
print('Mean score : ',score.mean()*100)
print('STD _score : ',score.std())
# Out:
# Cross_val_score :  77.40743409595869
# Mean score :  77.40743409595869
# STD _score :  0.0

# %%
pred_prob = DCT.predict_proba(test_xc)[:,1]
pred_prob
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
fpr,tpr,thresholds = roc_curve(test_yc,pred_prob,pos_label=True)

# %%
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.0104599  0.01112402 0.0142786  0.01577287 0.01693508
#  0.01710111 0.01909348 0.02008966 0.02075378 0.02241408 0.02291217
#  0.02324423 0.02407438 0.02590071 0.02839117 1.        ]
#
#
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#
#
# [2.         1.         0.92307692 0.86956522 0.75       0.66666667
#  0.5        0.45       0.18181818 0.16666667 0.15       0.14285714
#  0.125      0.11111111 0.03571429 0.03448276 0.        ]

# %%
#Plotting ROC Graph

plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'DCT')
plt.xlabel('False positive Rate')
plt.xlabel('True positive Rate')
plt.xlabel('DecisionTreeClassifier')
plt.show()
